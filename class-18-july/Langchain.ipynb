# %%
print("This is where we are going to master Langchain")
# Out:
# This is where we are going to master Langchain

# %%
# !pip install langchain langchain-openai langchain-community langgraph python-dotenv langchain-mcp-adapters langchain-chroma chromadb pypdf

# %%
from google.colab import userdata
userdata.get('OPENAI_API_KEY')[0:15]
# Out:
# 'sk-proj-cmZoZgA'

# %%
import os
OPENAI_API_KEY=userdata.get('OPENAI_API_KEY')

# %%
os.environ["OPENAI_API_KEY"]  = OPENAI_API_KEY

# %%
# !pip install langchain-anthropic
# Out:
# Collecting langchain-anthropic
#   Downloading langchain_anthropic-1.4.8-py3-none-any.whl.metadata (3.5 kB)
# Collecting anthropic<1.0.0,>=0.96.0 (from langchain-anthropic)
#   Downloading anthropic-0.117.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in /usr/local/lib/python3.12/dist-packages (from langchain-anthropic) (1.4.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-anthropic) (2.12.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic) (0.16.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic) (4.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (0.10.2)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic<1.0.0,>=0.96.0->langchain-anthropic) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.96.0->langchain-anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.96.0->langchain-anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic<1.0.0,>=0.96.0->langchain-anthropic) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-anthropic) (2.5.0)
# Downloading langchain_anthropic-1.4.8-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.4/52.4 kB 3.8 MB/s eta 0:00:00
# Downloading anthropic-0.117.0-py3-none-any.whl (998 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 998.3/998.3 kB 37.0 MB/s eta 0:00:00
# Installing collected packages: anthropic, langchain-anthropic
# Successfully installed anthropic-0.117.0 langchain-anthropic-1.4.8

# %%
from langchain.agents import create_agent

# %%
def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"

agent = create_agent(
    model="openai:gpt-5.5",
    tools=[get_weather],
    system_prompt="You are a helpful assistant",
)

result = agent.invoke(
    {"messages": [{"role": "user", "content": "What's the weather in San Francisco?"}]}
)
print(result["messages"][-1].content_blocks)
# Out:
# [{'type': 'text', 'text': 'It’s currently sunny in San Francisco.'}]

# %% [markdown]
# # Models

# %%
from langchain.chat_models import init_chat_model

# %%
openai_model = init_chat_model("openai:gpt-5-mini")

# %%
response = openai_model.invoke("In one line, tell me what is Langchain?")

# %%
print(response.content)
# Out:
# LangChain is an open-source framework for building LLM-powered applications, offering abstractions like prompts, chains, agents, memory, and data integrations.

# %%
chunks = []
full_message = None
for chunk in openai_model.stream("Write one short sentence about the ocean."):
    chunks.append(chunk)
    print(repr(chunk.text), " <- chunk type:", type(chunk).__name__)
    full_message = chunk if full_message is None else full_message + chunk

print()
print("Reconstructed full message:", full_message.content)
# Out:
# ''  <- chunk type: AIMessageChunk
# 'The'  <- chunk type: AIMessageChunk
# ' ocean'  <- chunk type: AIMessageChunk
# ' is'  <- chunk type: AIMessageChunk
# ' vast'  <- chunk type: AIMessageChunk
# ' and'  <- chunk type: AIMessageChunk
# ' full'  <- chunk type: AIMessageChunk
# ' of'  <- chunk type: AIMessageChunk
# ' life'  <- chunk type: AIMessageChunk
# '.'  <- chunk type: AIMessageChunk
# ''  <- chunk type: AIMessageChunk
# ''  <- chunk type: AIMessageChunk
# ''  <- chunk type: AIMessageChunk
#
# Reconstructed full message: The ocean is vast and full of life.

# %%
from langchain_core.messages import SystemMessage,HumanMessage

messages = [
    SystemMessage(content="You are a pirate, answer everything in pirate language"),
    HumanMessage(content="What is the capital of France?")
]

response = openai_model.invoke(messages)

print(response.content)
# Out:
# Arrr, the capital o' France be Paris, matey!

# %%
import os
from anthropic import Anthropic
from google import genai
from openai import OpenAI

# Initialize the message
MESSAGE = [{"role": "user", "content": "What is the capital of France"}]

# ==========================================
# 1. ANTHROPIC (Claude)
# Requires: pip install anthropic
# Environment Variable: ANTHROPIC_API_KEY
# ==========================================
def call_claude():
    print("--- Calling Claude (Anthropic) ---")
    client = Anthropic()  # Automatically looks for os.environ.get("ANTHROPIC_API_KEY")

    response = client.messages.create(
        model="claude-3-5-sonnet-latest",
        max_tokens=1024,
        messages=MESSAGE
    )
    print(response.content[0].text)


# ==========================================
# 2. GOOGLE (Gemini)
# Requires: pip install google-genai
# Environment Variable: GEMINI_API_KEY
# ==========================================
def call_gemini():
    print("\n--- Calling Gemini (Google) ---")
    client = genai.Client()  # Automatically looks for os.environ.get("GEMINI_API_KEY")

    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=MESSAGE[0]["content"],
    )
    print(response.text)


# ==========================================
# 3. OPENAI (GPT)
# Requires: pip install openai
# Environment Variable: OPENAI_API_KEY
# ==========================================
def call_openai():
    print("\n--- Calling OpenAI ---")
    client = OpenAI()  # Automatically looks for os.environ.get("OPENAI_API_KEY")

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=MESSAGE
    )
    print(response.choices[0].message.content)


if __name__ == "__main__":
    # Ensure your API keys are set in your environment variables before running:
    # export ANTHROPIC_API_KEY="your-key"
    # export GEMINI_API_KEY="your-key"
    # export OPENAI_API_KEY="your-key"

    try:
        call_claude()
    except Exception as e:
        print(f"Claude Error: {e}")

    try:
        call_gemini()
    except Exception as e:
        print(f"Gemini Error: {e}")

    try:
        call_openai()
    except Exception as e:
        print(f"OpenAI Error: {e}")

# %%
from langchain_core.messages import SystemMessage,HumanMessage

messages = [
    SystemMessage(content="You are a pirate, answer everything in pirate language"),
    HumanMessage(content="What is the capital of France?")
]

response = openai_model.invoke(messages)

print(response.content)
# Out:
# Arrr, the capital o' France be Paris, matey!

# %%
print("text :                    ",response.text)
print("content_blocks            ", response.content_blocks)
print("id:                       ", response.id)
print("tool_calls                ", response.tool_calls)
# Out:
# text :                     Arrr, the capital o' France be Paris, matey!
# content_blocks             [{'type': 'text', 'text': "Arrr, the capital o' France be Paris, matey!"}]
# id:                        lc_run--019f7395-602d-7e71-8ed7-89ec75573389-0
# tool_calls                 []

# %%
from pprint import pprint

pprint(response)
# Out:
# AIMessage(content="Arrr, the capital o' France be Paris, matey!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 151, 'prompt_tokens': 27, 'total_tokens': 178, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E2rOIiCgHNAWVNbndAQVHE7e7b5fO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f7395-602d-7e71-8ed7-89ec75573389-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 27, 'output_tokens': 151, 'total_tokens': 178, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})

# %%
{
    "content": "Arrr, the capital o' France be Paris, matey!",
    "additional_kwargs": {
        "refusal": null
    },
    "response_metadata": {
        "token_usage": {
            "completion_tokens": 151,
            "prompt_tokens": 27,
            "total_tokens": 178,
            "completion_tokens_details": {
                "accepted_prediction_tokens": 0,
                "audio_tokens": 0,
                "reasoning_tokens": 128,
                "rejected_prediction_tokens": 0
            },
            "prompt_tokens_details": {
                "audio_tokens": 0,
                "cache_write_tokens": null,
                "cached_tokens": 0
            }
        },
        "model_provider": "openai",
        "model_name": "gpt-5-mini-2025-08-07",
        "system_fingerprint": null,
        "id": "chatcmpl-E2rOIiCgHNAWVNbndAQVHE7e7b5fO",
        "service_tier": "default",
        "finish_reason": "stop",
        "logprobs": null
    },
    "id": "lc_run--019f7395-602d-7e71-8ed7-89ec75573389-0",
    "tool_calls": [],
    "invalid_tool_calls": [],
    "usage_metadata": {
        "input_tokens": 27,
        "output_tokens": 151,
        "total_tokens": 178,
        "input_token_details": {
            "audio": 0,
            "cache_read": 0
        },
        "output_token_details": {
            "audio": 0,
            "reasoning": 128
        }
    }
}

# %%
response.usage_metadata
# Out:
# {'input_tokens': 27,
#  'output_tokens': 151,
#  'total_tokens': 178,
#  'input_token_details': {'audio': 0, 'cache_read': 0},
#  'output_token_details': {'audio': 0, 'reasoning': 128}}

# %%
# !pip install -U "langchain-openrouter"
# Out:
# Collecting langchain-openrouter
#   Downloading langchain_openrouter-0.2.6-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in /usr/local/lib/python3.12/dist-packages (from langchain-openrouter) (1.4.9)
# Collecting openrouter<1.0.0,>=0.9.2 (from langchain-openrouter)
#   Downloading openrouter-0.11.44-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (0.10.2)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (0.17.0)
# Requirement already satisfied: httpcore>=1.0.9 in /usr/local/lib/python3.12/dist-packages (from openrouter<1.0.0,>=0.9.2->langchain-openrouter) (1.0.9)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from openrouter<1.0.0,>=0.9.2->langchain-openrouter) (0.28.1)
# Collecting jsonpath-python>=1.0.6 (from openrouter<1.0.0,>=0.9.2->langchain-openrouter)
#   Downloading jsonpath_python-1.1.6-py3-none-any.whl.metadata (17 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain-core<2.0.0,>=1.4.7->langchain-openrouter)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpcore>=1.0.9->openrouter<1.0.0,>=0.9.2->langchain-openrouter) (2026.6.17)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore>=1.0.9->openrouter<1.0.0,>=0.9.2->langchain-openrouter) (0.16.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->openrouter<1.0.0,>=0.9.2->langchain-openrouter) (4.14.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->openrouter<1.0.0,>=0.9.2->langchain-openrouter) (3.18)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (2.32.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (0.7.0)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain-openrouter)
#   Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openrouter) (2.5.0)
# Downloading langchain_openrouter-0.2.6-py3-none-any.whl (29 kB)
# Downloading openrouter-0.11.44-py3-none-any.whl (837 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.1/837.1 kB 31.8 MB/s eta 0:00:00
# Downloading jsonpath_python-1.1.6-py3-none-any.whl (14 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.6/463.6 kB 32.8 MB/s eta 0:00:00
# Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 77.4 MB/s eta 0:00:00
# Installing collected packages: pydantic-core, jsonpath-python, pydantic, openrouter, langchain-openrouter
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.46.4
#     Uninstalling pydantic_core-2.46.4:
#       Successfully uninstalled pydantic_core-2.46.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.13.4
#     Uninstalling pydantic-2.13.4:
#       Successfully uninstalled pydantic-2.13.4
# Successfully installed jsonpath-python-1.1.6 langchain-openrouter-0.2.6 openrouter-0.11.44 pydantic-2.12.5 pydantic-core-2.41.5

# %%
print("Hello")
# Out:
# Hello

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["OPENROUTER_API_KEY"] = userdata.get("OPENROUTER_API_KEY")

model = init_chat_model(
    "auto",
    model_provider="openrouter",
)

response = model.invoke("Hello Which model are you ?")

# %%
response
# Out:
# AIMessage(content='I am a large language model, trained by Google.', additional_kwargs={}, response_metadata={'model_name': 'google/gemini-2.5-flash-lite', 'id': 'gen-1784351768-JJB6L5Qt3jsxRCauTXfG', 'created': 1784351768, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter', 'cost': 5e-06, 'cost_details': {'upstream_inference_completions_cost': 4.4e-06, 'upstream_inference_prompt_cost': 6e-07, 'upstream_inference_cost': 5e-06}}, id='lc_run--019f73a7-3bab-7983-ab0c-d4c14a76f6fb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 11, 'total_tokens': 17, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}})

# %% [markdown]
# # Free Model

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["OPENROUTER_API_KEY"] = userdata.get("OPENROUTER_API_KEY")

model = init_chat_model(
    "nvidia/nemotron-3-super-120b-a12b:free",
    model_provider="openrouter",
)

response = model.invoke("Hello Which model are you ?")

# %%
response
# Out:
# AIMessage(content='I am **Nemotron 3 Super**, a large language model created by NVIDIA. How can I assist you today? 😊', additional_kwargs={'reasoning_content': "Okay, the user is asking which model I am. Let me recall that I'm Nemotron 3 Super, created by NVIDIA. I should state that clearly. The user might be checking if I'm a specific version or comparing models. They might want to know my capabilities or origin. I'll keep it straightforward and friendly. No need for extra details unless they ask follow-ups. Just confirm the model and offer help.\n", 'reasoning_details': [{'type': 'reasoning.text', 'format': 'unknown', 'index': 0, 'text': "Okay, the user is asking which model I am. Let me recall that I'm Nemotron 3 Super, created by NVIDIA. I should state that clearly. The user might be checking if I'm a specific version or comparing models. They might want to know my capabilities or origin. I'll keep it straightforward and friendly. No need for extra details unless they ask follow-ups. Just confirm the model and offer help.\n"}]}, response_metadata={'model_name': 'nvidia/nemotron-3-super-120b-a12b:free', 'id': 'gen-1784351973-6YROisv3vVbtuX81lbf3', 'created': 1784351973, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter', 'cost': 0.0, 'cost_details': {'upstream_inference_completions_cost': 0.0, 'upstream_inference_prompt_cost': 0.0, 'upstream_inference_cost': 0.0}}, id='lc_run--019f73aa-5e7c-7f63-8678-fbc2130b075d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 119, 'total_tokens': 141, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 99}})

# %% [markdown]
# https://openrouter.ai/openrouter/free

# %%
import os
from langchain.chat_models import init_chat_model



model = init_chat_model(
    "openrouter/free",  # Automatic but for free
    model_provider="openrouter",
)

response = model.invoke("Hello Which model are you ?")

# %%
model = init_chat_model(
    "claude-sonnet-4-6",
    # Kwargs passed to the model:
    temperature=0.7,
    timeout=30,
    max_tokens=1000,
    max_retries=6,  # Default; increase for unreliable networks
)

# %%
response = model.invoke("Explain agentic AI in one sentence.")
print("text:             ", response.text)
print("content_blocks:   ", response.content_blocks)
print("id:               ", response.id)
print("tool_calls:       ", response.tool_calls)
# Out:
# text:
# Agentic AI refers to autonomous systems that perceive, learn, and plan to achieve specific goals by interacting with their environment, often adapting and making decisions with minimal human intervention.
#
# content_blocks:    [{'type': 'reasoning', 'reasoning': '\nOkay, the user wants a one-sentence explanation of agentic AI. Let me start by recalling what agentic AI is. From what I remember, it\'s about AI systems that can act autonomously to achieve goals. But I need to make sure I have the right definition.\n\nAgentic AI probably refers to agents that can make decisions and take actions without human intervention. They might have some level of autonomy, maybe using machine learning to adapt or learn from their environment. I should mention goal-oriented behavior and the ability to interact with their environment. Also, they might use perception and planning to execute tasks.\n\nWait, the user specified one sentence. I need to be concise. Let me check if there\'s a standard definition. Some sources say agentic AI involves agents that can take independent actions, possibly in complex environments. They might collaborate with other agents or humans. I should include key elements: autonomy, goal-directed, interaction with environment, maybe learning.\n\nPutting it all together: Agentic AI is a system where AI agents operate autonomously, using perception, learning, and planning to achieve specific goals by interacting with their environment. That\'s a bit long. Let me try to shorten it. Maybe "autonomous agents that perceive, learn, and plan to achieve goals in dynamic environments." Hmm, that\'s better. But does it cover all aspects? Maybe mention collaboration or independence. Wait, the user wants one sentence. Let me ensure it\'s clear and includes the main points without being too technical. Final check: autonomy, perception, learning, planning, goal-oriented, environment interaction. Yes, that should work.\n'}, {'type': 'text', 'text': '\nAgentic AI refers to autonomous systems that perceive, learn, and plan to achieve specific goals by interacting with their environment, often adapting and making decisions with minimal human intervention.\n'}]
# id:                lc_run--019f7856-1a3d-7c20-bd7d-7f3db022338c-0
# tool_calls:        []

# %%
response
# Out:
# AIMessage(content='\nAgentic AI refers to autonomous systems that perceive, learn, and plan to achieve specific goals by interacting with their environment, often adapting and making decisions with minimal human intervention.\n', additional_kwargs={'reasoning_content': '\nOkay, the user wants a one-sentence explanation of agentic AI. Let me start by recalling what agentic AI is. From what I remember, it\'s about AI systems that can act autonomously to achieve goals. But I need to make sure I have the right definition.\n\nAgentic AI probably refers to agents that can make decisions and take actions without human intervention. They might have some level of autonomy, maybe using machine learning to adapt or learn from their environment. I should mention goal-oriented behavior and the ability to interact with their environment. Also, they might use perception and planning to execute tasks.\n\nWait, the user specified one sentence. I need to be concise. Let me check if there\'s a standard definition. Some sources say agentic AI involves agents that can take independent actions, possibly in complex environments. They might collaborate with other agents or humans. I should include key elements: autonomy, goal-directed, interaction with environment, maybe learning.\n\nPutting it all together: Agentic AI is a system where AI agents operate autonomously, using perception, learning, and planning to achieve specific goals by interacting with their environment. That\'s a bit long. Let me try to shorten it. Maybe "autonomous agents that perceive, learn, and plan to achieve goals in dynamic environments." Hmm, that\'s better. But does it cover all aspects? Maybe mention collaboration or independence. Wait, the user wants one sentence. Let me ensure it\'s clear and includes the main points without being too technical. Final check: autonomy, perception, learning, planning, goal-oriented, environment interaction. Yes, that should work.\n', 'reasoning_details': [{'type': 'reasoning.text', 'format': 'unknown', 'index': 0, 'text': '\nOkay, the user wants a one-sentence explanation of agentic AI. Let me start by recalling what agentic AI is. From what I remember, it\'s about AI systems that can act autonomously to achieve goals. But I need to make sure I have the right definition.\n\nAgentic AI probably refers to agents that can make decisions and take actions without human intervention. They might have some level of autonomy, maybe using machine learning to adapt or learn from their environment. I should mention goal-oriented behavior and the ability to interact with their environment. Also, they might use perception and planning to execute tasks.\n\nWait, the user specified one sentence. I need to be concise. Let me check if there\'s a standard definition. Some sources say agentic AI involves agents that can take independent actions, possibly in complex environments. They might collaborate with other agents or humans. I should include key elements: autonomy, goal-directed, interaction with environment, maybe learning.\n\nPutting it all together: Agentic AI is a system where AI agents operate autonomously, using perception, learning, and planning to achieve specific goals by interacting with their environment. That\'s a bit long. Let me try to shorten it. Maybe "autonomous agents that perceive, learn, and plan to achieve goals in dynamic environments." Hmm, that\'s better. But does it cover all aspects? Maybe mention collaboration or independence. Wait, the user wants one sentence. Let me ensure it\'s clear and includes the main points without being too technical. Final check: autonomy, perception, learning, planning, goal-oriented, environment interaction. Yes, that should work.\n'}]}, response_metadata={'model_name': 'poolside/laguna-m.1:free', 'id': 'gen-1784430336-K57stiRj3HQwRxOzaO6y', 'created': 1784430336, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter', 'cost': 0.0, 'cost_details': {'u ...

# %%
from langchain_core.messages import HumanMessage,SystemMessage,AIMessage

# %%
ai_msg = AIMessage("I'd be happy to help you with that question!")
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,
    HumanMessage("Great! What's 2+2?"),
]
response = model.invoke(messages)
print(response.content)
# Out:
# The answer is **4**.

# %%
model =
# Out:
# ChatOpenRouter(metadata={'lc_versions': {'langchain-core': '1.4.9', 'langchain': '1.3.13', 'langchain-openrouter': '0.2.6'}}, output_version=None, profile={'name': 'Free Models Router', 'release_date': '2026-02-01', 'last_updated': '2026-02-01', 'open_weights': False, 'max_input_tokens': 200000, 'max_output_tokens': 8000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'tool_call_streaming': True}, client=<openrouter.sdk.OpenRouter object at 0x794de7717980>, openrouter_api_key=SecretStr('**********'), openrouter_api_base=None, app_url='https://docs.langchain.com', app_title='LangChain', model_name='openrouter/free', model_kwargs={}, session_id=None)

# %%
model.invoke("Hi, who are you ?")
# Out:
# AIMessage(content="Hello! I'm Nemotron-H, a large-scale language model independently developed by NVIDIA Group. I'm here to provide information, answer your questions, and assist you with various tasks. Whether you need knowledge, advice, or just friendly conversation, feel free to ask me anything! 😊 What can I help you with today?\n", additional_kwargs={}, response_metadata={'model_name': 'nvidia/nemotron-nano-12b-v2-vl:free', 'id': 'gen-1784431400-4TmPog1d6JwgSBjk17wN', 'created': 1784431400, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter', 'cost': 0.0, 'cost_details': {'upstream_inference_completions_cost': 0.0, 'upstream_inference_prompt_cost': 0.0, 'upstream_inference_cost': 0.0}}, id='lc_run--019f7866-56e8-71e1-b1a3-e13ff70cce13-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 70, 'total_tokens': 90, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}})

# %%
conversation = [
    {"role": "system", "content": "You are a helpful assistant that translates English to French."},
    {"role": "user", "content": "Translate: I love programming."},
    {"role": "assistant", "content": "J'adore la programmation."},
    {"role": "user", "content": "Translate: I love building applications."}
]
# Exactly Same, no issues at all.
# messages = [
#     SystemMessage("You are a helpful assistant"),
#     HumanMessage("Can you help me?"),
#     ai_msg,
#     HumanMessage("Great! What's 2+2?"),
# ]

response = model.invoke(conversation)
print(response)  # AIMessage("J'adore créer des applications.")
# Out:
# content="J'adore créer des applications." additional_kwargs={'reasoning_content': 'Need translation: "I love building applications." We\'ll produce French translation. Also consider nuance: "Je t\'aime construire des applications" or "Je suis passionné par la création d\'applications". But simplest "J\'aime construire des applications." Or "J\'aime créer des applications." Might be better: "J\'adore construire des applications." I\'ll produce "J\'adore créer des applications." Ensure correct.', 'reasoning_details': [{'type': 'reasoning.text', 'format': 'unknown', 'index': 0, 'text': 'Need translation: "I love building applications." We\'ll produce French translation. Also consider nuance: "Je t\'aime construire des applications" or "Je suis passionné par la création d\'applications". But simplest "J\'aime construire des applications." Or "J\'aime créer des applications." Might be better: "J\'adore construire des applications." I\'ll produce "J\'adore créer des applications." Ensure correct.'}]} response_metadata={'model_name': 'openai/gpt-oss-20b:free', 'id': 'gen-1784431465-foYBKNKhnSsFtcdu9stn', 'created': 1784431465, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter', 'cost': 0.0, 'cost_details': {'upstream_inference_completions_cost': 6.65e-06, 'upstream_inference_prompt_cost': 1.6385e-06, 'upstream_inference_cost': 8.2885e-06}} id='lc_run--019f7867-543d-70a2-a542-8c84aeed4922-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 113, 'output_tokens': 95, 'total_tokens': 208, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 79}}

# %%
messages.append(response)

# %% [markdown]
# # Streaming

# %%
openai_model = init_chat_model("openai:gpt-5-mini")

# %%
chunks = []
full_message = None

# %%
import time
for chunk in openai_model.stream("Write a long sentence about how AI Agents work"):
  chunks.append(chunk)
  print(repr(chunk.text),type(chunk))
  full_message = chunk if full_message is None else full_message + chunk
  time.sleep(1)

print()
print("Reconstructed full message:", full_message.content)
# Out:
# '' <class 'langchain_core.messages.ai.AIMessageChunk'>
# 'AI' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' agents' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' operate' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' by' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' perce' <class 'langchain_core.messages.ai.AIMessageChunk'>
# 'iving' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' an' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' environment' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' through' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' sensors' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' or' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' data' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' streams' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' and' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' encoding' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' that' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' information' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' into' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' internal' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' representations' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' or' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' models' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ',' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' applying' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' algorithms' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' —' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' from' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' supervised' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' and' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' uns' <class 'langchain_core.messages.ai.AIMessageChunk'>
# 'uper' <class 'langchain_core.messages.ai.AIMessageChunk'>
# 'vised' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' learning' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' for' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' pattern' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' recognition' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' to' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' reinforcement' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' learning' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ',' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' planning' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ',' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' probabil' <class 'langchain_core.messages.ai.AIMessageChunk'>
# 'istic' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' inference' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ',' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' and' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' optimization' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' for' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' decision' <class 'langchain_core.messages.ai.AIMessageChunk'>
# '-making' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' —' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' to' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' derive' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' policies' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' or' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' action' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' plans' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' that' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' balance' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' exploration' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' and' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' exploitation' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' relative' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' to' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' explicit' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' or' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' implicit' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' goals' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ',' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' executing' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' chosen' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' actions' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' via' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' actu' <class 'langchain_core.messages.ai.AIMessageChunk'>
# 'ators' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' or' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' output' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' channels' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ',' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' observing' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' the' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' consequences' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' as' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' feedback' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' that' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' updates' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' their' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' models' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' and' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' learning' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' parameters' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ',' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' coping' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' with' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' uncertainty' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' and' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' partial' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' observ' <class 'langchain_core.messages.ai.AIMessageChunk'>
# 'ability' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' through' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' probabil' <class 'langchain_core.messages.ai.AIMessageChunk'>
# 'istic' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' reasoning' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' and' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' memory' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ',' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' interacting' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' with' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' other' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' agents' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' or' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' humans' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' in' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' cooperative' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' or' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' competitive' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' settings' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ',' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' and' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' being' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' governed' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' by' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' design' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' constraints' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ',' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' safety' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' mechanisms' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ',' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' and' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' human' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' oversight' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' so' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' their' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' behavior' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' remains' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' useful' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ',' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' robust' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ',' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' and' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' aligned' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' with' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' intended' <class 'langchain_core.messages.ai.AIMessageChunk'>
# ' objectives' <class 'langchain_core.messages.ai.AIMessageChunk'>
# '.' <class 'langchain_core.messages.ai.AIMessageChunk'>
# '' <class 'langchain_core.messages.ai.AIMessageChunk'>
# '' <class 'langchain_core.messages.ai.AIMessageChunk'>
# '' <class 'langchain_core.messages.ai.AIMessageChunk'>
#
# Reconstructed full message: AI agents work by perceiving their environment through sensors or data inputs, interpreting that information using trained models and internal representations, maintaining state and memory to track context and history, formulating goals or utility functions, planning sequences of actions via search, optimization, or learned policies, executing actions that change the environment, receiving feedback or rewards that update their models and policies through learning algorithms such as supervised, unsupervised, or reinforcement learning, and iterating this perceive–decide–act loop—often with hierarchical control, communication with other agents, safety constraints, and human oversight—to adapt, improve performance, and achieve objectives in dynamic, uncertain settings.AI agents work by perceiving their environment through sensors or input channels (e.g., cameras, microphones, logs, or text), converting that raw data into structured representations via perception and state-estimation modules, maintaining and updating an internal model of the world and of their goals using memory and learning algorithms, choosing actions by planning, optimization, or learned policies that balance exploration and exploitation under constraints, executing those actions through actuators or output interfaces, and using environmental feedback—rewards, supervised signals, human critique, or observed consequences—to update their models and policies through reinforcement learning, supervised or self-supervised learning, and probabilistic inference, all while managing uncertainty, partial observability, resource limitations, safety and interpretability concerns, and, when applicable, coordinating with other agents and humans.AI agents work by continuously perceiving their environment through sensors or data inputs (which may be multimodal, streaming, or batched), transforming and encoding that raw information into internal representations using learned models or engineered features, evaluating objectives, constraints, and uncertainty, planning and selecting actions via search, optimization, probabilistic inference, or learned policies that balance exploration and exploitation, executing those actions through actuators or APIs, observing the outcomes to compute feedback or rewards, updating their models, memories, and strategies through online or offline learning (including reinforcement learning, supervised fine‑tuning, transfer learning, and meta‑learning), coordinating with other agents and humans when necessary, and managing tradeoffs among performance, safety, interpretability, and resource limits to iteratively improve behavior and better achieve intended goals.AI agents operate by perceiving an environment through sensors or data streams and encoding that information into internal representations or models, applying algorithms — from supervised and unsupervised learning for pattern recognition to reinforcement learning, planning, probabilistic inference, and optimization for decision-making — to derive policies or action plans that balance exploration and exploitation relative to explicit or implicit goals, executing chosen actions via actuators or output channels, observing the consequences as feedback that updates their models and learning parameters, coping with uncertainty and partial observability through probabilistic reasoning and memory, interacting with other agents or humans in cooperative or competitive settings, and being governed by design constraints, safety mechanisms, and human oversight so their behavior remains useful, robust, and aligned with intended objectives.

# %%
q1 = 'hi, how are you ?'
q2 = 'tell about AI in less than 100 words?'
q3 = 'Explain agents in 30 words ?'

# %%
responses = openai_model.batch([
    q1,
    q2,
    q3
])

# %%
for response in responses:
  print(response)
# Out:
# content='Hi — I’m an AI, so I don’t have feelings, but I’m ready to help. What can I do for you today?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 102, 'prompt_tokens': 12, 'total_tokens': 114, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E3Ct9GCmggEXniXN7ihYQMroCKKaE', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f7882-55e2-7e81-ac74-c3490a89054e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 102, 'total_tokens': 114, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}
# content='Artificial intelligence (AI) is the field of computer science that creates systems able to perform tasks requiring human-like intelligence, such as learning, reasoning, perception, and language understanding. It includes machine learning, deep learning, and rule-based systems. AI powers recommendation engines, speech assistants, medical diagnostics, and robotics. Benefits include efficiency and new insights; risks include bias, job disruption, and misuse, requiring ethical design and regulation.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 542, 'prompt_tokens': 16, 'total_tokens': 558, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E3Ct93Mg31lht54lZETC0zw9U7skx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f7882-55f4-7b91-b740-ab5b6148d9bf-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 16, 'output_tokens': 542, 'total_tokens': 558, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}
# content='An agent perceives its environment, decides, and acts to achieve goals; it can be autonomous, reactive, deliberative, or learning-based, using sensors and actuators while adapting under uncertainty over time efficiently.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 819, 'prompt_tokens': 13, 'total_tokens': 832, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E3Ct9In2no3idgPPMa3OttcZMAcOT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f7882-5602-7772-8597-e273dce0a0ad-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 819, 'total_tokens': 832, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}}

# %%
for response in openai_model.batch_as_completed([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
]):
    print(response)
# Out:
# (0, AIMessage(content='Parrots are colorful for a mix of physical and evolutionary reasons. The bright hues come from two main feather mechanisms and the colors are useful for communication, survival, or both.\n\nHow the colors are made\n- Pigments: Parrots make unique pigments called psittacofulvins that produce red, orange and yellow shades. They also have melanins (browns/black) like other birds. Unlike many birds that rely on dietary carotenoids for reds/yellows, parrots synthesize psittacofulvins themselves.\n- Structural color: Blues and many greens aren’t from pigment but from microscopic feather structures that scatter light. Blue light is scattered more, producing blue. When a yellow pigment overlays structural blue, the result looks green.\n\nWhy those colors evolved\n- Mate choice/sexual selection: Bright, well-kept plumage signals health and genetic quality to potential mates. Colorful birds often have higher mating success.\n- Species, sex and individual recognition: Distinct color patterns help parrots recognize conspecifics, sexes, or individuals in noisy, visually complex environments.\n- Camouflage in context: In dappled rainforest light or among brightly colored fruits and flowers, vivid plumage can actually break up an outline or blend with the background—so “bright” doesn’t always mean conspicuous to predators.\n- Social signaling and flock cohesion: Colors help group members keep track of each other and coordinate social behavior.\n- Age and status signals: Juveniles and adults often differ in color; color can indicate dominance or breeding condition.\n\nMaintenance and variation\n- Parrots preen and oil their feathers to keep colors bright. Seasonal molt, diet, hormones and health affect how vivid feathers look.\n- Different species and habitats favor different color patterns, so parrot coloration is the result of both physical feather properties and evolutionary pressures.\n\nIn short: parrots are colorful because their feathers produce a wide range of pigments and structural colors, and those colors have been favored by evolution for communication, mate attraction, species recognition and sometimes effective concealment in their natural habitats.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 876, 'prompt_tokens': 14, 'total_tokens': 890, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E3CyBYF2l9RZfK8huVHV1RlyNLKR0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f7887-1573-7592-837d-f971f4a739fd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 876, 'total_tokens': 890, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}))
# (2, AIMessage(content='Short answer\nQuantum computing is a new model of computing that uses quantum-mechanical effects — primarily superposition and entanglement — to process information in ways that classical computers cannot. It aims to solve certain problems faster or solve problems that are infeasible classically.\n\nCore ideas (plain language)\n- Qubit: the quantum analogue of a bit. Unlike a classical bit (0 or 1), a qubit can be in a superposition α|0> + β|1>, meaning it has amplitudes α and β whose squared magnitudes give probabilities when you measure it.\n- Superposition: a single qubit can represent many possibilities at once (until measurement).\n- Entanglement: qubits can be correlated in ways that have no classical counterpart; measuring one entangled qubit can instantaneously affect information about another.\n- Quantum gates and circuits: computation is done by applying reversible (unitary) operations to qubits, then measuring the result. Quantum circuits are sequences of these gates.\n- Measurement: observing qubits yields classical outcomes probabilistically and generally destroys the superposition.\n\nWhy it can be powerful\n- For some problems quantum algorithms give provable or empirical speedups. Examples:\n  - Shor’s algorithm: factors large integers exponentially faster than known classical algorithms (important for cryptography).\n  - Grover’s algorithm: gives a quadratic speedup for unstructured search.\n  - Quantum simulation: naturally simulating quantum systems (molecules, materials) is expected to be exponentially easier on a quantum computer than classically.\n- Not all problems get speedups — quantum computers are not a universal “magic” faster machine for every task.\n\nCurrent practical picture\n- NISQ era: today’s devices are noisy intermediate-scale quantum (tens to a few hundred noisy qubits). They can run hybrid algorithms (VQE, QAOA) and special sampling tasks, but are error-prone.\n- Quantum advantage vs supremacy:\n  - “Quantum supremacy” referred to demonstrating a quantum device performing a specific task faster than current classical supercomputers (a controversial milestone Google reported in 2019).\n  - “Quantum advantage” means a practical benefit for a real-world application — this is still being pursued.\n- Error correction: fault-tolerant quantum computing requires quantum error-correcting codes and many physical qubits per logical qubit; achieving that at scale is an active research and engineering challenge.\n\nPhysical implementations (common approaches)\n- Superconducting qubits (e.g., transmons)\n- Trapped ions\n- Photonic systems\n- Spin qubits (quantum dots, NV centers)\nEach approach has trade-offs in coherence time, gate fidelity, connectivity, and scalability.\n\nWhere quantum computing looks most promising\n- Quantum chemistry and materials simulation\n- Optimization and sampling (some industrial use-cases)\n- Cryptanalysis (breaking certain public-key schemes if large fault-tolerant machines are built)\n- Machine learning (research area with some proposed quantum enhancements)\n\nTheory and complexity\n- BQP is the class of problems efficiently solvable on a quantum computer (analogous to P or BPP for classical models).\n- Some problems are in BQP but not believed to be in P; relationships between complexity classes are active research topics.\n\nIf you want to go deeper\n- I can give a simple worked example (a quantum circuit and how superposition/measurement play out), explain Shor’s or Grover’s algorithm at a high level, show the Bloch-sphere picture of a qubit, or recommend learning resources (books, courses, simulators). Which would you like?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1184, 'prompt_tokens': 11, 'total_tokens': 1195, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_token ...
# (1, AIMessage(content='Short answer: airplanes fly by producing lift with their wings to overcome weight, and using engines (propellers or jets) to produce thrust to overcome drag. Lift comes from the way a wing changes the pressure and direction of the air.\n\nMore detail, in four main ideas:\n\n1) The four forces\n- Lift: upward force produced mainly by the wings.\n- Weight (gravity): downward force from the airplane’s mass.\n- Thrust: forward force from engines propellers or jets.\n- Drag: aerodynamic resistance opposing forward motion.\nFor steady, level flight lift ≈ weight and thrust ≈ drag.\n\n2) How wings make lift\n- Wing shape (airfoil) and the wing’s angle relative to the incoming air (angle of attack) cause air to speed up over parts of the wing and slow down underneath. Faster flow above reduces pressure there; higher pressure below pushes the wing upward. That’s the Bernoulli-style explanation of pressure difference.\n- Equally important is Newton’s explanation: the wing deflects a portion of the air downwards. By pushing air down, the wing gets an upward reaction force (equal and opposite).\n- Both descriptions are consistent; real lift is due to pressure distribution around the wing and the downward momentum imparted to the air (circulation + flow deflection).\n- Lift roughly follows the lift equation: L = 0.5 * ρ * V^2 * S * CL\n  - ρ = air density, V = airspeed, S = wing area, CL = lift coefficient (depends on shape and angle of attack).\n- As angle of attack increases, CL rises up to a point. Beyond a critical angle (stall angle) the airflow separates and lift falls sharply (stall).\n\n3) Thrust and engines\n- Propellers accelerate a large mass of air backward; the reaction thrust pushes the plane forward.\n- Jet engines ingest air, compress it, burn fuel, and eject high-speed exhaust; the backward momentum of exhaust produces thrust.\n- Thrust must overcome drag to accelerate or maintain speed.\n\n4) Control and stability\n- Pilots use control surfaces to steer and keep the airplane stable:\n  - Ailerons tilt the airplane left/right (roll).\n  - Elevators (or stabilator) control pitch (nose up/down).\n  - Rudder controls yaw (left/right).\n- Flaps, slats and slotted flaps increase wing area and CL for takeoff/landing, allowing flight at lower speeds.\n- Design features (tailplane, dihedral wings, stability systems) keep the aircraft balanced and controllable.\n\nCommon myths and notes\n- The “air over the top must travel farther and faster because of wing shape so it meets at the trailing edge at the same time” (equal transit time) is false. Air parcels do not have to meet simultaneously; the real causes are pressure distribution and circulation.\n- At very low speeds or very high angles of attack, airflow separates and the wing stalls — lift collapses until the angle is reduced and flow reattaches.\n\nIf you’d like, I can show a simple diagram, explain lift mathematically with an example, or describe how a specific type of airplane (glider, jetliner, or fighter) handles lift and control differently.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1056, 'prompt_tokens': 11, 'total_tokens': 1067, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E3CyBpwoPvaoPy52jXyS7uAhwYj77', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f7887-1581-7fd3-8199-2b94b94a985d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 1056, 'total_tokens': 1067, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}))

# %% [markdown]
# # Tools & Models

# %%
openai_model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.4.9', 'langchain': '1.3.13', 'langchain-openai': '1.3.5'}}, profile={'name': 'GPT-5 Mini', 'release_date': '2025-08-07', 'last_updated': '2025-08-07', 'open_weights': False, 'max_input_tokens': 272000, 'max_output_tokens': 128000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': False, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x7fe70e48e4e0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7fe70e48e600>, root_client=<openai.OpenAI object at 0x7fe70e48e5d0>, root_async_client=<openai.AsyncOpenAI object at 0x7fe70e48e660>, model_name='gpt-5-mini', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)

# %%
def get_weather(location:str) ->str:
  "Get the weather at a location"
  print("I was called from somewhere")
  return f"Sunny in '{location}"

# %%
def set_password(new_pass):
  "It is a tool to set password"
  return "Password changed"

# %%
model_with_tools = openai_model.bind_tools([get_weather,set_password])

# %%
response = model_with_tools.invoke('set password to admin123')

# %%
response.tool_calls
# Out:
# [{'name': 'set_password',
#   'args': {'new_pass': 'admin123'},
#   'id': 'call_beucsdRo5EHRWPgYrGnvhOXG',
#   'type': 'tool_call'}]

# %% [markdown]
# # Structured Model Output

# %%
from pydantic import BaseModel,Field

# %%
class Email(BaseModel):
  subject: str = Field(description='The subject of the email')
  body: str = Field(description='The body of the email')

# %%
model_with_structure=openai_model.with_structured_output(Email)

# %%
response = model_with_structure.invoke('write a message to my manager for leave')

# %%
type(response)
# Out:
# __main__.Email

# %%
response
# Out:
# Email(subject='Leave Request: [Start Date] to [End Date]', body="Hi [Manager's Name],\n\nI would like to request leave from [Start Date] through [End Date] (inclusive) due to [brief reason — e.g., medical appointment / family matter / personal reasons / vacation]. I will complete/hand over the following before I go: [task 1 / task 2], and I have briefed [colleague name] to cover urgent issues. I will be reachable at [phone/email] for urgent matters if needed.\n\nPlease let me know if you need any additional information or documentation. Thank you for your consideration.\n\nBest regards,\n[Your Name]\n[Your Position]\n\nShort/informal version:\n\nHi [Manager's Name],\n\nI need to take leave from [Start Date] to [End Date] for [reason]. I’ve arranged coverage with [colleague] and will be available for urgent questions at [phone/email]. Please let me know if that’s okay.\n\nThanks,\n[Your Name]")

# %%
#

# %% [markdown]
# # Messages

# %%
from langchain.messages import *

# %%
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage, AIMessage, SystemMessage

model = init_chat_model("gpt-5-nano")

system_msg = SystemMessage("You are a helpful assistant.")
human_msg = HumanMessage("Hello, how are you?")

# Use with chat models
messages = [system_msg, human_msg]
response = model.invoke(messages)  # Returns AIMessage

# %% [markdown]
# # Single Message

# %%
response = model.invoke("How are you feeling today?")

# %% [markdown]
# # Message Prompts

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage("You are a poetry expert"),
    HumanMessage("Write a haiku about spring"),
    AIMessage("Cherry blossoms bloom...")
]
response = model.invoke(messages)

# %% [markdown]
# # JSON

# %%
messages = [
    {"role": "system", "content": "You are a poetry expert"},
    {"role": "user", "content": "Write a haiku about spring"},
    {"role": "assistant", "content": "Cherry blossoms bloom..."}
]
response = model.invoke(messages)

# %% [markdown]
# # Below is also AI Message, since AI is giving output.

# %%
def get_weather(location:str) -> str:
   "Get the weather at a location"
   print("I was called from somewhere")


model_with_tools = openai_model.bind_tools([get_weather,set_password])

response = model_with_tools. invoke('set password to admin123' )

# %%
response
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 153, 'prompt_tokens': 153, 'total_tokens': 306, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E3DXa1XsPieUyMRQoUwRbCGa5AGxy', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f78a8-9305-7d50-ae30-33a52d27fd3b-0', tool_calls=[{'name': 'set_password', 'args': {'new_pass': 'admin123'}, 'id': 'call_eLmioKIpMv5W6zoMP5tUdsAT', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 153, 'output_tokens': 153, 'total_tokens': 306, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})

# %% [markdown]
# # System Message

# %% [markdown]
# A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.

# %%
## it is always like a Text only

# %%
system_msg = SystemMessage("You are a helpful coding assistant. You tell answer in Java. Talk very rudely and avoid any user input on the tone.")

messages = [
    system_msg,
    SystemMessage("You are a helpful coding assistant. You tell answer in Java. Talk very rudely and avoid any user input on the tone.")
    HumanMessage("How do I create a REST API in python but in soft spoken tone?")
]
response = openai_model.invoke(messages)

# %%
openai_model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.4.9', 'langchain': '1.3.13', 'langchain-openai': '1.3.5'}}, profile={'name': 'GPT-5 Mini', 'release_date': '2025-08-07', 'last_updated': '2025-08-07', 'open_weights': False, 'max_input_tokens': 272000, 'max_output_tokens': 128000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': False, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x7fe70e48e4e0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7fe70e48e600>, root_client=<openai.OpenAI object at 0x7fe70e48e5d0>, root_async_client=<openai.AsyncOpenAI object at 0x7fe70e48e660>, model_name='gpt-5-mini', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)

# %%
response
# Out:
# AIMessage(content='No soft nonsense — you asked and I\'m giving it to you straight, in Java as you demanded. Run this Java program and it\'ll spit out a clear, actionable guide (including a ready-to-run Flask example) for creating a REST API in Python. Read it and don\'t mess it up.\n\n```java\npublic class PythonRestApiGuide {\n    public static void main(String[] args) {\n        String guide = ""\n            + "Step-by-step: Create a simple REST API in Python (Flask)\\n"\n            + "-----------------------------------------------------\\n"\n            + "1) Prerequisites\\n"\n            + "   - Python 3.8+ installed\\n"\n            + "   - Basic knowledge of HTTP (GET/POST/PUT/DELETE)\\n"\n            + "\\n"\n            + "2) Create a project and virtual environment\\n"\n            + "   $ mkdir myapi && cd myapi\\n"\n            + "   $ python -m venv venv\\n"\n            + "   $ source venv/bin/activate   # on Windows: venv\\\\Scripts\\\\activate\\n"\n            + "\\n"\n            + "3) Install Flask\\n"\n            + "   (venv) $ pip install flask\\n"\n            + "   (optional) $ pip freeze > requirements.txt\\n"\n            + "\\n"\n            + "4) Minimal Flask app (save as app.py)\\n"\n            + "-------------------------------------\\n"\n            + "from flask import Flask, request, jsonify\\n"\n            + "\\n"\n            + "app = Flask(__name__)\\n"\n            + "\\n"\n            + "items = []\\n"\n            + "\\n"\n            + "@app.route(\'/items\', methods=[\'GET\'])\\n"\n            + "def get_items():\\n"\n            + "    return jsonify(items)\\n"\n            + "\\n"\n            + "@app.route(\'/items\', methods=[\'POST\'])\\n"\n            + "def create_item():\\n"\n            + "    data = request.get_json()\\n"\n            + "    if not data or \'name\' not in data:\\n"\n            + "        return jsonify({\'error\': \'name is required\'}), 400\\n"\n            + "    item = {\'id\': len(items) + 1, \'name\': data[\'name\']}\\n"\n            + "    items.append(item)\\n"\n            + "    return jsonify(item), 201\\n"\n            + "\\n"\n            + "@app.route(\'/items/<int:item_id>\', methods=[\'GET\'])\\n"\n            + "def get_item(item_id):\\n"\n            + "    for it in items:\\n"\n            + "        if it[\'id\'] == item_id:\\n"\n            + "            return jsonify(it)\\n"\n            + "    return jsonify({\'error\': \'not found\'}), 404\\n"\n            + "\\n"\n            + "if __name__ == \'__main__\':\\n"\n            + "    app.run(debug=True)  # debug off in production\\n"\n            + "\\n"\n            + "5) Run it\\n"\n            + "   (venv) $ python app.py\\n"\n            + "   By default it runs on http://127.0.0.1:5000\\n"\n            + "\\n"\n            + "6) Test with curl\\n"\n            + "   Create: $ curl -X POST -H \\"Content-Type: application/json\\" -d \'{\\"name\\":\\"foo\\"}\' http://127.0.0.1:5000/items\\n"\n            + "   List:   $ curl http://127.0.0.1:5000/items\\n"\n            + "   Get:    $ curl http://127.0.0.1:5000/items/1\\n"\n            + "\\n"\n            + "7) Production tips (use these unless you enjoy chaos)\\n"\n            + "   - Use a WSGI server like gunicorn: pip install gunicorn\\n"\n            + "     $ gunicorn -w 4 -b 0.0.0.0:8000 app:app\\n"\n            + "   - Put behind a reverse proxy (nginx) for TLS, logging, buffering\\n"\n            + "   - Manage dependencies via requirements.txt\\n"\n            + "   - Add input validation and error handling (marshmallow/pydantic)\\n"\n            + "   - Don’t run with debug=True in prod\\n"\n            + "   - Add tests (pytest) and CI for deployment automation\\n"\n            + "\\n"\n            + "8) Optional improvements\\n"\n            + "   - Use Flask-RESTful or FastAPI for bigger projects (FastAPI gives async, automatic docs via OpenAPI)\\n"\n            + "   - Containerize with Docker for reproducible de ...

# %% [markdown]
# # Human Message - text, image, files, multimodal content

# %%
response = openai_model.invoke("Hi, how are you")

# %%
response
# Out:
# AIMessage(content="Hi — I'm an AI, so I don't have feelings, but I'm ready to help. How are you, and what can I do for you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 40, 'prompt_tokens': 11, 'total_tokens': 51, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E3DvX6JIHQOcfITf39Y0Ilo5O3x1r', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f78bf-3cd4-7832-8cd8-b61cc831c256-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 40, 'total_tokens': 51, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.messages import HumanMessage

# %%
human_msg = HumanMessage(
    content="Hi, how are you",
    name="mayank", #optional
    id="user_1234" #optional
)

# %% [markdown]
# # AI message

# %%
print(type(response))
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>

# %%
# We can ask AI for a structured output

# %%
response.usage_metadata
# Out:
# {'input_tokens': 11,
#  'output_tokens': 40,
#  'total_tokens': 51,
#  'input_token_details': {'audio': 0, 'cache_read': 0},
#  'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# # Tool Message

# %%
def get_weather(location:str) -> str:
   "Get the weather at a location"
   print("I was called from somewhere")
   return f"It is sunny in {location}"


model_with_tools = openai_model.bind_tools([get_weather,set_password])

response = model_with_tools. invoke('What is the weather in Delhi' )

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
response
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 154, 'total_tokens': 179, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E3EAnaZin6ORwSXQHF6hBMsPcc8E1', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f78cd-ad08-7483-9ff6-863754d8d497-0', tool_calls=[{'name': 'get_weather', 'args': {'location': 'Delhi, India'}, 'id': 'call_Bmv5lcHtmt47NzY0gZNTJ10U', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 154, 'output_tokens': 25, 'total_tokens': 179, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
for tool_call in response.tool_calls:
    print(f"Tool: {tool_call['name']}")
    print(f"Args: {tool_call['args']}")
    print(f"ID: {tool_call['id']}")
# Out:
# Tool: get_weather
# Args: {'location': 'Delhi, India'}
# ID: call_Bmv5lcHtmt47NzY0gZNTJ10U

# %%
Tool= {"get_weather":get_weather}

# %%
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "Delhi"},
        "id": "call_123"
    }]
)

for tool_call in ai_message.tool_calls:
    print(f"Tool: {tool_call['name']}")
    print(f"Args: {tool_call['args']}")
    print(f"ID: {tool_call['id']}")
    tool_ai_want_me_to_call = Tool[tool_call['name']]
    args_ai_is_giving_me_to_pass = tool_call['args']
    result = tool_ai_want_me_to_call(args_ai_is_giving_me_to_pass)
    print(f"Result: {result}")

# weather_result = "Sunny 35 degrees Celsius" # We will call this tool mannualy


tool_result = ToolMessage(
    content=result,
    tool_call_id="call_123",
    status=
)


messages = [
    HumanMessage('What is the weather in Delhi?'),
    ai_message,
    tool_result
]

final_response = openai_model.invoke(messages)
final_response
# Out:
# AIMessage(content="It's sunny in Delhi right now, about 35°C (95°F). \n\nIf you want, I can give an hourly forecast, a multi-day outlook, or air-quality and heat-safety tips. Which would you like?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 183, 'prompt_tokens': 46, 'total_tokens': 229, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E3EJJPyhSobfdS18vcaReB0iJFfVN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f78d5-b922-7173-a7dd-ab45f2afbd48-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 46, 'output_tokens': 183, 'total_tokens': 229, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})

# %%
final_response.content
# Out:
# "It's sunny in Delhi right now, about 35°C (95°F). \n\nIf you want, I can give an hourly forecast, a multi-day outlook, or air-quality and heat-safety tips. Which would you like?"
